# %%
import os

image_path = './images'

names = []
for filename in os.listdir(image_path):
    if filename.endswith('.jpg') or filename.endswith('.JPG'):
        names.append(filename)

print("JPEG files:", names[:5])
# Out:
# JPEG files: ['21631250_2382537283.jpg', '22152031_2938781276.jpg', '22612593_1277143998.jpg', '20648015_1759089945.jpg', '21789171_3507298778.jpg']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
image_path = f'/projectnb/cs585/zzzz_OCR/SimpleOCR/images/{names[25]}'
img = mpimg.imread(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers and ticks
plt.show()
